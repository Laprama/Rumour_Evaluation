# %%
import sys
sys.path.append('data_extraction/')
sys.path.append('preprocessing/')

# %%
from reddit_data_extraction import *
from twitter_data_extraction import *
from preprocessing_twitter import *

# %% [markdown]
# ## Data

# %%
training_data_zip = ('data/rumoureval-2019-training-data.zip')
training_data_directory = ZipFile(training_data_zip)
training_data_contents = get_directory_structure(training_data_directory)

# %%
reddit_train_data = training_data_contents['reddit-training-data']
reddit_dev_data = training_data_contents['reddit-dev-data']

# %%
twitter_english = training_data_contents['twitter-english']

# %% [markdown]
# ### Data Labels

# %%
train_labels = json.loads(training_data_directory.read('rumoureval-2019-training-data/train-key.json'))
dev_labels = json.loads(training_data_directory.read('rumoureval-2019-training-data/dev-key.json'))

# %% [markdown]
# ### Extract data

# %%
train, dev = get_twitter_data(training_data_directory, twitter_english, train_labels, dev_labels)

# %%
train[['text', 'depth', 'split', 'task_A_label']]
# Out:
#                                                    text  depth  split  \
# 0     MT @euronews France: 10 dead after shooting at...      1  train
# 1     @j0nathandavis They who? Stupid and partial op...      2  train
# 2     @nanoSpawn Socialists, Antisemites, anti zioni...      3  train
# 3     @euronews @TradeDesk_Steve A French crime of p...      1  train
# 4     @euronews LOL. 5 million Muslims in France, wh...      1  train
# ...                                                 ...    ...    ...
# 5563                         @emaccaz_ omfg it is 😱😱😱😱😱      2  train
# 5564  @Angus_OL thank god they're all safe now. some...      1  train
# 5565  @Angus_OL thank god its over, they're finally ...      1  train
# 5566                                       @Angus_OL :(      1  train
# 5567  Police confirm that #sydneysiege is finally ov...      0  train
#
#      task_A_label
# 0         comment
# 1            deny
# 2         comment
# 3           query
# 4         comment
# ...           ...
# 5563      comment
# 5564      support
# 5565      comment
# 5566      comment
# 5567      support
#
# [4519 rows x 4 columns]

# %% [markdown]
# ### Feature Engineering

# %%
train = build_feature(train, build_hashtag_feature, 'hashtag_feature')
train = build_feature(train, build_url_feature, 'url_feature')

# %% [markdown]
# ### Cleaning Text

# %%
# %%capture
train = build_feature(train, clean_text, 'cleaned_text')

# %%
train.head()
# Out:
#   contributors  truncated hashtag_feature url_feature  \
# 0         None      False            None        None
# 1         None      False            None        None
# 2         None      False            None        None
# 3         None      False            None        None
# 4         None      False            None        None
#
#                                         cleaned_text  \
# 0  MT @euronews France: 10 dead after shooting at...
# 1  @j0nathandavis They who? Stupid and partial op...
# 2  @nanoSpawn Socialists, Antisemites, anti zioni...
# 3  @euronews @TradeDesk_Steve A French crime of p...
# 4  @euronews LOL. 5 million Muslims in France, wh...
#
#                                                 text  in_reply_to_status_id  \
# 0  MT @euronews France: 10 dead after shooting at...           5.527837e+17
# 1  @j0nathandavis They who? Stupid and partial op...           5.527854e+17
# 2  @nanoSpawn Socialists, Antisemites, anti zioni...           5.527862e+17
# 3  @euronews @TradeDesk_Steve A French crime of p...           5.527837e+17
# 4  @euronews LOL. 5 million Muslims in France, wh...           5.527837e+17
#
#                    id  favorite_count  \
# 0  552785374507175936               2
# 1  552786226546495488               0
# 2  552789345628069888               0
# 3  552792862610694144               0
# 4  552943855021330432               0
#
#                                               source  ...  possibly_sensitive  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...  ...                 NaN
# 1  <a href="http://itunes.apple.com/us/app/twitte...  ...                 NaN
# 2  <a href="http://twitter.com" rel="nofollow">Tw...  ...                 NaN
# 3  <a href="http://twitter.com/download/android" ...  ...                 NaN
# 4  <a href="http://twitter.com" rel="nofollow">Tw...  ...                 NaN
#
#   extended_entities task_B_label filter_level metadata  \
# 0               NaN          NaN          NaN      NaN
# 1               NaN          NaN          NaN      NaN
# 2               NaN          NaN          NaN      NaN
# 3               NaN          NaN          NaN      NaN
# 4               NaN          NaN          NaN      NaN
#
#    possibly_sensitive_appealable  is_quote_status  quoted_status_id  \
# 0                            NaN              NaN               NaN
# 1                            NaN              NaN               NaN
# 2                            NaN              NaN               NaN
# 3                            NaN              NaN               NaN
# 4                            NaN              NaN               NaN
#
#   quoted_status quoted_status_id_str
# 0           NaN                  NaN
# 1           NaN                  NaN
# 2           NaN                  NaN
# 3           NaN                  NaN
# 4           NaN                  NaN
#
# [5 rows x 38 columns]

# %% [markdown]
# ### Tokenising (not implemented yet)

# %% [markdown]
# ...
